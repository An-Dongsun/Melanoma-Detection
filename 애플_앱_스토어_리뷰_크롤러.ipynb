# %% [markdown]
# <a href="https://colab.research.google.com/github/An-Dongsun/Melanoma-Detection/blob/main/%EC%95%A0%ED%94%8C_%EC%95%B1_%EC%8A%A4%ED%86%A0%EC%96%B4_%EB%A6%AC%EB%B7%B0_%ED%81%AC%EB%A1%A4%EB%9F%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 애플 앱 스토어 리뷰 크롤러
# * 참고: https://kibua20.tistory.com/196

# %%
# !pip install xmltodict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %% [markdown]
# # 메디팡팡

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1550889868
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=2/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=3/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=4/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=5/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=6/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=7/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=8/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=9/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=10/id=1550889868/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1550889868/sortBy=mostRecent/xml
# Save reviews to file: appstore_1550889868.csv

# %% [markdown]
# # 모비닥

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1621486623
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1621486623/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1621486623/sortBy=mostRecent/xml
# Save reviews to file: appstore_1621486623.csv

# %% [markdown]
# # 엠디톡

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1495296101
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1495296101/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1495296101/sortBy=mostRecent/xml
# Save reviews to file: appstore_1495296101.csv

# %% [markdown]
# # 굿닥

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 517637141
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=2/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=3/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=4/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=5/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=6/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=7/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=8/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=9/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=10/id=517637141/sortby=mostrecent/xml?urlDesc=/customerreviews/id=517637141/sortBy=mostRecent/xml
# Save reviews to file: appstore_517637141.csv

# %% [markdown]
# # 올라케어

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1538105223
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=2/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=3/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=4/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=5/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=6/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=7/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=8/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=9/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=10/id=1538105223/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1538105223/sortBy=mostRecent/xml
# Save reviews to file: appstore_1538105223.csv

# %% [markdown]
# # 나만의닥터

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1584940053
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=2/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=3/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=4/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=5/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=6/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=7/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=8/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=9/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=10/id=1584940053/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1584940053/sortBy=mostRecent/xml
# Save reviews to file: appstore_1584940053.csv

# %% [markdown]
# # 닥터온

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1565924524
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1565924524/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1565924524/sortBy=mostRecent/xml
# Save reviews to file: appstore_1565924524.csv

# %% [markdown]
# # 똑닥
# * 병원 예약/접수 약국찾기

# %%
import pandas as pd
import xmltodict
import requests
import os


def get_url_index(url):
    response = requests.get(url).content.decode('utf8')
    xml = xmltodict.parse(response)

    last_url = [l['@href'] for l in xml['feed']['link'] if (l['@rel'] == 'last')][0]
    last_index = [int(s.replace('page=', '')) for s in last_url.split('/') if ('page=' in s)][0]

    return last_index

# https://stackoverflow.com/questions/1090282/api-to-monitor-iphone-app-store-reviews
def appstore_crawler(appid, outfile='./appstore_reviews.csv'):
    url = 'https://itunes.apple.com/kr/rss/customerreviews/page=1/id=%i/sortby=mostrecent/xml' % appid

    try:
        last_index = get_url_index(url)
    except Exception as e:
        print (url)
        print ('\tNo Reviews: appid %i' %appid)
        print ('\tException:', e)
        return

    result = list()
    for idx in range(1, last_index+1):
        url = "https://itunes.apple.com/kr/rss/customerreviews/page=%i/id=%i/sortby=mostrecent/xml?urlDesc=/customerreviews/id=%i/sortBy=mostRecent/xml" % (idx, appid, appid)
        print(url)

        response = requests.get(url).content.decode('utf8')
        try:
            xml = xmltodict.parse(response)
        except Exception as e:
            print ('\tXml Parse Error %s\n\tSkip %s :' %(e, url))
            continue

        try:
            num_reivews= len(xml['feed']['entry'])
        except Exception as e:
            print ('\tNo Entry', e)
            continue

        try:
            xml['feed']['entry'][0]['author']['name']
            single_reviews = False
        except:
            #print ('\tOnly 1 review!!!')
            single_reviews = True
            pass

        if single_reviews:
                result.append({
                    'USER': xml['feed']['entry']['author']['name'],
                    'DATE': xml['feed']['entry']['updated'],
                    'STAR': int(xml['feed']['entry']['im:rating']),
                    'LIKE': int(xml['feed']['entry']['im:voteSum']),
                    'TITLE': xml['feed']['entry']['title'],
                    'REVIEW': xml['feed']['entry']['content'][0]['#text'],
                })
        else:
            for i in range(len(xml['feed']['entry'])):
                result.append({
                    'USER': xml['feed']['entry'][i]['author']['name'],
                    'DATE': xml['feed']['entry'][i]['updated'],
                    'STAR': int(xml['feed']['entry'][i]['im:rating']),
                    'LIKE': int(xml['feed']['entry'][i]['im:voteSum']),
                    'TITLE': xml['feed']['entry'][i]['title'],
                    'REVIEW': xml['feed']['entry'][i]['content'][0]['#text'],
                })

    res_df = pd.DataFrame(result)
    res_df['DATE'] = pd.to_datetime(res_df['DATE'], format="%Y-%m-%dT%H:%M:%S")
    res_df.to_csv(outfile, encoding='utf-8-sig', index=False)
    print ('Save reviews to file: %s \n' %(outfile))


if __name__ == '__main__':
    # https://apps.apple.com/us/app/youtube-watch-listen-stream/id544007664
    app_id = 1014889755
    outfile = os.path.join('appstore_' + str(app_id)+'.csv')
    appstore_crawler(app_id, outfile=outfile)
# Out:
# https://itunes.apple.com/kr/rss/customerreviews/page=1/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=2/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=3/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=4/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=5/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=6/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=7/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=8/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=9/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# https://itunes.apple.com/kr/rss/customerreviews/page=10/id=1014889755/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1014889755/sortBy=mostRecent/xml
# Save reviews to file: appstore_1014889755.csv
